# %%
import PyPDF2 as pdf2
import joblib
import re


import nltk
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk import  word_tokenize
from nltk.probability import FreqDist
from nltk import  blankline_tokenize
from nltk.util import bigrams, trigrams,ngrams
from nltk.stem import PorterStemmer
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
from autocorrect import Speller 
from spacy.matcher import Matcher 

from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

import spacy
nlp=spacy.load('en_core_web_sm')

# %%
from tabula.io import read_pdf
bok = "docs/PMBOK 5th.pdf"
pmi = "docs/PMIPracticeStandardforProjectRiskManagement.pdf"
# [top,left,bottom,width]
box_bok = [1.425, 0, 25.386, 19.947]
box_pmi = [3.366, 0, 27.25, 24]
fc=28.28
for i in range(0, len(box_bok)):
    box_bok[i] *= fc
    
for i in range(0, len(box_pmi)):
    box_pmi[i] *= fc

t_bok = read_pdf(bok, pages=list(range(335, 380)),area=[box_bok],output_format="json", stream=True)
t_pmi = read_pdf(pmi, pages=list(range(13, 67)),area=[box_pmi],output_format="json", stream=True)

# %% [markdown]
# # Get Data Json Format

# %%
all_data_bok=[]
for i in range(len(t_bok)):
    all_data_bok.append(t_bok[i]['data'])
    
    
all_data_pmi=[]
for i in range(len(t_pmi)):
    all_data_pmi.append(t_pmi[i]['data'])

# %% [markdown]
# # Flatten the list

# %%
data_bok = [item for sublist in all_data_bok for item in sublist]

data_pmi = [item for sublist in all_data_pmi for item in sublist]

# %%
text_bok=[]
for i in range(len(data_bok)):
    text_bok.append(data_bok[i][0]['text'])
    
    
text_pmi=[]
for i in range(len(data_pmi)):
    text_pmi.append(data_pmi[i][0]['text'])

# %%
text_bok = [i for i in text_bok if i !='']
text_pmi = [i for i in text_pmi if i !='']

# %%
text_bok_lda = [i for i in text_bok if i !='']
text_pmi_lda = [i for i in text_pmi if i !='']

# %% [markdown]
# # String Text

# %%
text_bok = " ".join([str(elem) for elem in text_bok])
text_pmi = " ".join([str(elem) for elem in text_pmi])

# %% [markdown]
# ## Remove newlines & Tabs

# %%
def remove_newlines_tabs(text):    
    # Replacing all the occurrences of \n,\\n,\t,\\ with a space.
    Formatted_text = text.replace('\\n', ' ').replace('\n', ' ').replace('\t',' ').replace('\\', ' ')
    return Formatted_text
text_bok = remove_newlines_tabs(text_bok)
text_pmi = remove_newlines_tabs(text_pmi)

# %% [markdown]
# ## Case Conversion

# %%
def lower_casing_text(text):
    text = text.lower()
    return text
text_bok = lower_casing_text(text_bok)
text_pmi = lower_casing_text(text_pmi)

# %% [markdown]
# ##  Remove Special Characters

# %%
def removing_special_characters(text):
    text="".join([i for i in text if i.isalpha() or i==" " or i ==',' or i =='.'])
    return text
text_bok = removing_special_characters(text_bok)
text_pmi = removing_special_characters(text_pmi)

# %% [markdown]
# ## Expand Contractions

# %%
CONTRACTION_MAP = joblib.load('docs/CONTRACTION_MAP')
def expand_contractions(text, contraction_mapping =  CONTRACTION_MAP):
    list_Of_tokens = text.split(' ')    
    for Word in list_Of_tokens: 
         if Word in CONTRACTION_MAP: 
                list_Of_tokens = [item.replace(Word, CONTRACTION_MAP[Word]) for item in list_Of_tokens]                
    String_Of_tokens = ' '.join(str(e) for e in list_Of_tokens) 
    return String_Of_tokens
text_bok = expand_contractions(text_bok)
text_pmi = expand_contractions(text_pmi)

# %% [markdown]
# ## Remove Stopwords

# %%
stoplist = stopwords.words('english') 
stoplist = set(stoplist)
def removing_stopwords(text):
    text = repr(text)
    No_StopWords = [word for word in word_tokenize(text) if word.lower() not in stoplist ]
    words_string = ' '.join(No_StopWords)   
    words_string=words_string.replace('\'','').replace('``','')
    return words_string
text_bok = removing_stopwords(text_bok)
text_pmi = removing_stopwords(text_pmi)

# %% [markdown]
# ##  Correcting Mis-spelled words

# %%
def spelling_correction(text):
    spell = Speller(lang='en')
    Corrected_text = spell(text)
    return Corrected_text
text_bok = spelling_correction(text_bok)
text_pmi = spelling_correction(text_pmi)

# %% [markdown]
# ## Sentence Tokenization

# %%
sent_bok = sent_tokenize(text_bok)
sent_pmi = sent_tokenize(text_pmi)

# %% [markdown]
# ##  Tokenization

# %%
def tokenization(text):
    tokens=word_tokenize(text)
    return tokens
text_bok = tokenization(text_bok)
text_pmi = tokenization(text_pmi)

# %% [markdown]
# ##  Bigram

# %%
bi_bok = list(nltk.bigrams(text_bok))

bi_pmi = list(nltk.bigrams(text_pmi))

# %% [markdown]
# ##  Lemmatization

# %%
def lemma(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

text_bok_lemma = lemma(bi_bok)
text_pmi_lemma = lemma(bi_pmi)

# %%
flat_text_bok_lemma=[]
for i in range(len(text_bok_lemma)):
    flat_text_bok_lemma.append(' '.join(text_bok_lemma[i]))
    
flat_text_pmi_lemma=[]
for i in range(len(text_pmi_lemma)):
    flat_text_pmi_lemma.append(' '.join(text_pmi_lemma[i]))

# %%
flat_text_bok_lemma
# Out:
# ['project risk',
#  'risk management',
#  'management project',
#  'project risk',
#  'risk management',
#  'management include',
#  'include process',
#  'process conduct',
#  'conduct risk',
#  'risk management',
#  'management planning',
#  'planning',
#  'identification',
#  'identification',
#  'analysis',
#  'analysis',
#  'response',
#  'response planning',
#  'planning',
#  'control',
#  'control risk',
#  'risk project',
#  'project',
#  'objective',
#  '',
#  'project risk',
#  'risk management',
#  'management increase',
#  'increase likelihood',
#  '',
#  'impact positive',
#  'positive event',
#  'event',
#  '',
#  '',
#  '',
#  'impact negative',
#  'negative event',
#  'event',
#  'project',
#  'figure',
#  'figure provide',
#  'provide overview',
#  '',
#  'project risk',
#  'risk management',
#  'management process',
#  'process',
#  'follow',
#  'follow',
#  'plan',
#  'plan risk',
#  'risk',
#  'process',
#  'process define',
#  'define conduct',
#  'conduct risk',
#  'risk management',
#  'management activity',
#  'activity',
#  'project',
#  '',
#  'identify',
#  'identify risksthe',
#  'risksthe process',
#  'process determine',
#  'determine risk',
#  'risk may',
#  'may affect',
#  'affect project',
#  'project document',
#  'document characteristic',
#  'characteristic',
#  '',
#  'perform',
#  'perform qualitative',
#  'qualitative risk',
#  'risk',
#  'process',
#  'process prioritize',
#  'prioritize risk',
#  '',
#  'analysis action',
#  'action assess',
#  'assess combine',
#  'combine probability',
#  'probability occurrence',
#  'occurrence',
#  'impact',
#  '',
#  'perform',
#  'perform quantitative',
#  'quantitative risk',
#  'risk',
#  'process',
#  'process numerically',
#  'numerically analyze',
#  'analyze effect',
#  'effect identify',
#  'identify risk',
#  'risk overall',
#  'overall project',
#  'project objective',
#  'objective',
#  '',
#  'plan',
#  'plan risk',
#  'risk',
#  'process',
#  'process develop',
#  'develop option',
#  'option action',
#  'action enhance',
#  'enhance opportunity',
#  'opportunity reduce',
#  'reduce threat',
#  '',
#  'project objective',
#  'objective',
#  '',
#  '',
#  'control',
#  'risksthe process',
#  'process implement',
#  'implement risk',
#  'risk response',
#  'response plan',
#  'plan',
#  'tracking',
#  'identify',
#  'identify risk',
#  'risk',
#  'monitoring',
#  'monitor',
#  'residual risk',
#  'risk',
#  'identify',
#  'identify new',
#  'new risk',
#  'risk',
#  'evaluate',
#  'evaluate risk',
#  'risk process',
#  'process effectiveness',
#  'effectiveness',
#  'project',
#  'project',
#  'process',
#  'process interact',
#  'process',
#  'process knowledge',
#  'knowledge area',
#  'area describe',
#  'describe detail',
#  'detail section',
#  '',
#  'a.',
#  '',
#  'project risk',
#  'risk uncertain',
#  'uncertain event',
#  'event condition',
#  'condition',
#  'occur',
#  'occur',
#  'positive',
#  'positive negative',
#  'negative effect',
#  'effect',
#  'project',
#  'project objective',
#  'objective scope',
#  '',
#  'schedule',
#  'schedule',
#  'cost',
#  'cost',
#  'quality',
#  'quality',
#  'risk',
#  'risk may',
#  'may',
#  'cause',
#  'cause',
#  'occur',
#  'occur',
#  'may',
#  'may',
#  'impact',
#  'impact',
#  '',
#  '',
#  'may give',
#  'give potential',
#  'potential requirement',
#  'requirement',
#  'assumption',
#  'assumption',
#  'constraint',
#  'constraint',
#  'condition',
#  'condition create',
#  'create possibility',
#  'negative',
#  'negative positive',
#  'positive outcome',
#  'outcome',
#  'example',
#  'example',
#  'cause',
#  'cause could',
#  'could include',
#  'include requirement',
#  'environmental',
#  'environmental permit',
#  'permit work',
#  'work',
#  'limited',
#  'limited personnel',
#  'personnel assign',
#  'assign design',
#  'design',
#  'project',
#  'risk',
#  'risk permit',
#  'permit',
#  'may',
#  'may take',
#  'take long',
#  'long plan',
#  'plan issue',
#  'issue',
#  '',
#  'case',
#  'case opportunity',
#  'opportunity',
#  'additional',
#  'additional development',
#  'development personnel',
#  'personnel may',
#  'may become',
#  'become available',
#  'available participate',
#  'participate design',
#  'design',
#  'assign',
#  'assign project',
#  'project',
#  'either',
#  'uncertain',
#  'uncertain event',
#  'event occur',
#  'occur',
#  'may',
#  'may impact',
#  'impact project',
#  'project',
#  '',
#  '',
#  'cost',
#  'cost',
#  'schedule',
#  'schedule',
#  'quality',
#  'quality',
#  'performance',
#  'performance',
#  'risk',
#  'risk condition',
#  'condition may',
#  'may include',
#  'include aspect',
#  'aspect project',
#  'project organization',
#  'organization',
#  'environment contribute',
#  'project',
#  'project risk',
#  'risk',
#  'immature',
#  'immature project',
#  'project management',
#  'management practice',
#  'practice',
#  'lack',
#  'lack integrate',
#  'integrated management',
#  'management',
#  'system',
#  'concurrent',
#  'concurrent multiple',
#  'multiple project',
#  'project',
#  '',
#  '',
#  'external participant',
#  'participant outside',
#  'outside project',
#  'project direct',
#  'direct control',
#  'control',
#  '',
#  'project risk',
#  'risk origin',
#  '',
#  'uncertainty present',
#  'present project',
#  'project',
#  'know',
#  'know risk',
#  'risk identify',
#  'analyze',
#  'analyze',
#  'make',
#  'make possible',
#  'possible plan',
#  'plan response',
#  'response risk',
#  'risk',
#  'know',
#  'know risk',
#  'risk manage',
#  'manage proactively',
#  'proactively',
#  'assign',
#  'assign',
#  '',
#  '',
#  'unknown',
#  'unknown risk',
#  'risk manage',
#  'manage proactively',
#  'proactively therefore',
#  'therefore may',
#  'may assign',
#  'assign management',
#  '',
#  '',
#  'negative',
#  'negative project',
#  'project risk',
#  'risk occur',
#  'occur consider',
#  'consider issue',
#  'issue',
#  'individual',
#  'individual project',
#  'project risk',
#  'risk different',
#  'different overall',
#  'overall project',
#  'project risk',
#  'risk',
#  'overall',
#  'overall project',
#  'project risk',
#  'risk represent',
#  'represent effect',
#  'effect',
#  'uncertainty project',
#  'project whole',
#  'whole',
#  '',
#  'sum individual',
#  'individual risk',
#  'risk',
#  'project',
#  'project',
#  '',
#  'include',
#  'include source',
#  'source',
#  'project uncertainty',
#  'uncertainty',
#  'represent',
#  'represent exposure',
#  'exposure stakeholder',
#  'stakeholder implication',
#  'implication',
#  '',
#  'project',
#  '',
#  'positive',
#  'positive negative',
#  'negative',
#  'organization',
#  'organization',
#  'perceive risk',
#  'risk effect',
#  'effect',
#  'uncertainty project',
#  'project organizational',
#  'organizational objective',
#  'objective',
#  'organization',
#  'organization stakeholder',
#  'stakeholder willing',
#  'willing',
#  'accept varying',
#  'vary degree',
#  'degree risk',
#  'risk depend',
#  'depend risk',
#  'risk attitude',
#  'attitude',
#  'risk',
#  'risk attitude',
#  '',
#  'organization stakeholder',
#  'stakeholder may',
#  'may influence',
#  'influence number',
#  'number factor',
#  'factor',
#  'broadly',
#  'broadly classified',
#  'classify',
#  'theme',
#  'theme risk',
#  'risk appetite',
#  '',
#  'degree',
#  'degree uncertainty',
#  'uncertainty entity',
#  'entity willing',
#  'willing take',
#  'take anticipation',
#  'anticipation reward',
#  'reward',
#  'risk',
#  'risk tolerance',
#  'tolerance',
#  'degree',
#  'degree',
#  'amount',
#  '',
#  'volume',
#  'volume risk',
#  'risk',
#  'organization',
#  'individual withstand',
#  'withstand',
#  'risk',
#  'risk threshold',
#  '',
#  'refer',
#  'refer measure',
#  'measure along',
#  'level',
#  'level uncertainty',
#  'uncertainty level',
#  'level impact',
#  'impact stakeholder',
#  'stakeholder may',
#  'may specific',
#  'specific interest',
#  'interest',
#  'risk',
#  'risk threshold',
#  '',
#  '',
#  'accept',
#  'accept risk',
#  'risk',
#  'risk',
#  'risk threshold',
#  '',
#  '',
#  'organization tolerate',
#  'tolerate risk',
#  'risk',
#  'example',
#  'example',
#  'organization',
#  'organization risk',
#  'risk attitude',
#  'attitude may',
#  'may include',
#  'include',
#  '',
#  'uncertainty',
#  'threshold',
#  'risk',
#  'risk level',
#  'level unacceptable',
#  'unacceptable',
#  'risk',
#  'risk tolerance',
#  'tolerance point',
#  '',
#  'organization may',
#  'may select',
#  'select different',
#  'different risk',
#  'risk response',
#  'response',
#  'positive',
#  'positive negative',
#  'negative risk',
#  'risk commonly',
#  'commonly refer',
#  'referred opportunity',
#  'opportunity threat',
#  'threat',
#  '',
#  'project may',
#  'accept',
#  'accept risk',
#  'risk',
#  'tolerance',
#  'tolerance balance',
#  'balance reward',
#  'reward may',
#  'gain',
#  'gain take',
#  'take risk',
#  'risk',
#  'positive',
#  'positive risk',
#  'risk offer',
#  'offer opportunity',
#  'opportunity',
#  'limit',
#  'limit risk',
#  'risk tolerance',
#  'tolerance may',
#  'may pursued',
#  'pursue order',
#  'order',
#  'enhance',
#  'enhance value',
#  'value',
#  'example',
#  'example',
#  'adopt',
#  'adopt aggressive',
#  'aggressive resource',
#  'resource optimization',
#  'optimization technique',
#  'technique risk',
#  'risk take',
#  'take anticipation',
#  'anticipation reward',
#  'reward use',
#  'use few',
#  'few resource',
#  'resource',
#  'individual',
#  'individual group',
#  'group adopt',
#  'attitude',
#  'attitude',
#  'risk',
#  'risk influence',
#  'influence way',
#  '',
#  '',
#  'risk',
#  'risk attitude',
#  'attitude drive',
#  'drive perception',
#  'perception',
#  'tolerance',
#  'tolerance',
#  'bias',
#  'bias',
#  'make',
#  'make explicit',
#  'explicit wherever',
#  'wherever possible',
#  'possible',
#  'consistent',
#  'consistent approach',
#  'risk',
#  'risk develop',
#  'develop project',
#  'project',
#  'communication',
#  'communication risk',
#  'risk handle',
#  'handle open',
#  'open honest',
#  'honest',
#  'risk',
#  'risk response',
#  'response reflect',
#  'reflect organization',
#  'organization perceive',
#  'perceive balance',
#  'balance risk',
#  'risk take',
#  'take risk',
#  'risk avoidance',
#  'avoidance',
#  'successful',
#  'successful',
#  '',
#  'commit',
#  'committed address',
#  'address risk',
#  'risk management',
#  'management proactively',
#  'proactively consistently',
#  'consistently',
#  'project',
#  'project',
#  'conscious',
#  'conscious choice',
#  'choice make',
#  'make level',
#  'level',
#  'organization actively',
#  'actively identify',
#  'identify',
#  'pursue effective',
#  'effective risk',
#  'risk management',
#  'management life',
#  'life',
#  'project',
#  '',
#  'project risk',
#  'risk could',
#  'could exist',
#  'exist moment',
#  '',
#  'project initiate',
#  'initiate',
#  'move',
#  'move forward',
#  '',
#  'project',
#  'proactive',
#  'proactive focus',
#  'focus risk',
#  'risk management',
#  'management likely',
#  'likely lead',
#  'lead problem',
#  'problem arise',
#  'arise unmanaged',
#  'threat',
#  'threat',
#  '',
#  '',
#  '',
#  '',
#  'perform',
#  'perform quantitative',
#  '',
#  '',
#  '',
#  '',
#  'plan',
#  'plan risk',
#  'risk management',
#  'management plan',
#  'plan risk',
#  'risk management',
#  'management process',
#  'process define',
#  'define conduct',
#  'conduct risk',
#  'risk management',
#  'management activity',
#  'activity',
#  'project',
#  'key',
#  'key benefit',
#  'benefit process',
#  'process ensure',
#  'ensure',
#  'degree',
#  'type',
#  'type',
#  'visibility',
#  'visibility risk',
#  'risk management',
#  'management',
#  'commensurate risk',
#  '',
#  'importance project',
#  '',
#  'organization',
#  'risk',
#  'risk management',
#  'management plan',
#  'plan vital',
#  'vital communicate',
#  'communicate obtain',
#  'obtain agreement',
#  'support',
#  'support stakeholder',
#  'stakeholder ensure',
#  'ensure risk',
#  'risk management',
#  'management process',
#  'process support',
#  'support perform',
#  'perform effectively',
#  'effectively project',
#  'project life',
#  'life cycle',
#  'cycle',
#  'input',
#  'input',
#  'tool',
#  'tool technique',
#  'technique',
#  'output',
#  'output process',
#  'process depict',
#  'depict figure',
#  'figure',
#  'figure',
#  'figure depict',
#  'depict',
#  'datum',
#  '',
#  'process',
#  'process',
#  'input',
#  'tool',
#  'tool technique',
#  'technique output',
#  'output',
#  '',
#  'project management',
#  'management plan',
#  'plan',
#  'analytical',
#  'analytical technique',
#  'technique',
#  'risk',
#  'risk management',
#  'management plan',
#  'plan',
#  '',
#  'project',
#  'charter',
#  'expert',
#  '',
#  'judgment',
#  'stakeholder',
#  'stakeholder',
#  'register',
#  'meeting',
#  'meeting',
#  'enterprise',
#  'enterprise',
#  'environmental factor',
#  'factor',
#  'organizational',
#  'organizational process',
#  'process asset',
#  'asset figure',
#  'figure',
#  'plan',
#  'plan risk',
#  'risk management',
#  'management input',
#  'input',
#  'tool',
#  'tool technique',
#  'technique',
#  'output',
#  '',
#  'project risk',
#  'risk management',
#  'management',
#  '',
#  'project',
#  'charter develop',
#  'develop project',
#  'project',
#  'charter',
#  'plan',
#  'plan risk',
#  'risk management',
#  'management',
#  'enterprise',
#  'enterprise develop',
#  'develop project',
#  'project',
#  'environmental management',
#  'management factor',
#  'factor risk',
#  'risk plan',
#  'plan',
#  'organizational',
#  'organizational',
#  'management management',
#  'management process',
#  'process asset',
#  'asset',
#  'plan plan',
#  'plan',
#  '',
#  'perform',
#  'perform',
#  'identify',
#  'identify quantitative',
#  '',
#  'identify risk',
#  'risk risk',
#  'risk analysis',
#  'analysis stakeholder',
#  'stakeholder stakeholder',
#  'stakeholder',
#  'register',
#  'perform',
#  'perform',
#  'qualitative',
#  'qualitative plan',
#  'plan risk',
#  'risk enterprise',
#  'enterprise risk',
#  'risk analysis',
#  'analysis response',
#  '',
#  'organization figure',
#  'figure',
#  'plan',
#  'plan risk',
#  'risk management',
#  '',
#  'datum',
#  '',
#  'careful',
#  'careful',
#  'explicit planning',
#  'planning enhance',
#  'enhance probability',
#  'probability success',
#  'success risk',
#  'risk management',
#  'management process',
#  'process',
#  'plan',
#  'planning also',
#  'also important',
#  'important provide',
#  'provide sufficient',
#  'sufficient resource',
#  'resource time',
#  'time risk',
#  'risk management',
#  'management activity',
#  'activity establish',
#  'establish agree',
#  'agree',
#  'basis',
#  'basis evaluate',
#  'evaluate risk',
#  'risk',
#  'plan',
#  'plan risk',
#  'risk management',
#  'management process',
#  'process begin',
#  'begin project',
#  'project conceive',
#  'complete',
#  'complete early',
#  'early project',
#  'project planning',
#  'planning',
#  '',
#  'plan',
#  'plan risk',
#  'risk management',
#  'management input',
#  'input',
#  '',
#  'project management',
#  'management plan',
#  'plan plan',
#  'plan risk',
#  'risk management',
#  'management',
#  'approve',
#  'approve subsidiary',
#  'subsidiary management',
#  'management plan',
#  'plan baseline',
#  'baseline take',
#  'take consideration',
#  'consideration order',
#  'order make',
#  'make risk',
#  'risk management',
#  'management plan',
#  'plan consistent',
#  'consistent',
#  'risk',
#  'risk management',
#  'management plan',
#  'plan also',
#  'also component',
#  '',
#  'project management',
#  'management plan',
#  'plan',
#  '',
#  'project management',
#  'management plan',
#  'plan provide',
#  'provide',
#  'current',
#  'current state',
#  'state riskaffecte',
#  'riskaffected area',
#  'area include',
#  'include scope',
#  '',
#  'schedule',
#  'schedule',
#  'cost',
#  'cost',
#  '',
#  '',
#  'project',
#  'describe',
#  'describe section',
#  'section',
#  'project',
#  'project',
#  'provide',
#  'provide various',
#  'various input',
#  'highlevel',
#  'risk',
#  'risk',
#  '',
#  '',
#  'project description',
#  'description',
#  '',
#  'highlevel requirement',
#  'requirement',
#  '',
#  'stakeholder',
#  'stakeholder',
#  'describe',
#  'describe section',
#  'section',
#  'stakeholder',
#  'stakeholder',
#  'register',
#  'contain',
#  'contain detail',
#  'detail related',
#  'related project',
#  'project stakeholder',
#  'stakeholder',
#  'provide',
#  'provide overview',
#  'role',
#  'role',
#  '',
#  'enterprise',
#  'enterprise',
#  'environmental factor',
#  'factor describe',
#  'describe section',
#  'section',
#  'enterprise',
#  'enterprise',
#  'environmental factor',
#  'factor',
#  'influence plan',
#  'plan risk',
#  'risk management',
#  'management process',
#  'process include',
#  'include',
#  'limited',
#  'limited',
#  'risk',
#  'risk attitude',
#  'attitude',
#  '',
#  'threshold',
#  'tolerance',
#  'tolerance describe',
#  '',
#  'degree risk',
#  'risk',
#  'organization',
#  'withstand',
#  '',
#  'organizational',
#  'organizational process',
#  'process asset',
#  'asset describe',
#  'describe section',
#  'section',
#  'organizational',
#  'organizational process',
#  'process asset',
#  ...]

# %%
flat_text_bok_lemma
# Out:
# ['project risk',
#  'risk management',
#  'management project',
#  'project risk',
#  'risk management',
#  'management include',
#  'include process',
#  'process conduct',
#  'conduct risk',
#  'risk management',
#  'management planning',
#  'planning',
#  'identification',
#  'identification',
#  'analysis',
#  'analysis',
#  'response',
#  'response planning',
#  'planning',
#  'control',
#  'control risk',
#  'risk project',
#  'project',
#  'objective',
#  '',
#  'project risk',
#  'risk management',
#  'management increase',
#  'increase likelihood',
#  '',
#  'impact positive',
#  'positive event',
#  'event',
#  '',
#  '',
#  '',
#  'impact negative',
#  'negative event',
#  'event',
#  'project',
#  'figure',
#  'figure provide',
#  'provide overview',
#  '',
#  'project risk',
#  'risk management',
#  'management process',
#  'process',
#  'follow',
#  'follow',
#  'plan',
#  'plan risk',
#  'risk',
#  'process',
#  'process define',
#  'define conduct',
#  'conduct risk',
#  'risk management',
#  'management activity',
#  'activity',
#  'project',
#  '',
#  'identify',
#  'identify risksthe',
#  'risksthe process',
#  'process determine',
#  'determine risk',
#  'risk may',
#  'may affect',
#  'affect project',
#  'project document',
#  'document characteristic',
#  'characteristic',
#  '',
#  'perform',
#  'perform qualitative',
#  'qualitative risk',
#  'risk',
#  'process',
#  'process prioritize',
#  'prioritize risk',
#  '',
#  'analysis action',
#  'action assess',
#  'assess combine',
#  'combine probability',
#  'probability occurrence',
#  'occurrence',
#  'impact',
#  '',
#  'perform',
#  'perform quantitative',
#  'quantitative risk',
#  'risk',
#  'process',
#  'process numerically',
#  'numerically analyze',
#  'analyze effect',
#  'effect identify',
#  'identify risk',
#  'risk overall',
#  'overall project',
#  'project objective',
#  'objective',
#  '',
#  'plan',
#  'plan risk',
#  'risk',
#  'process',
#  'process develop',
#  'develop option',
#  'option action',
#  'action enhance',
#  'enhance opportunity',
#  'opportunity reduce',
#  'reduce threat',
#  '',
#  'project objective',
#  'objective',
#  '',
#  '',
#  'control',
#  'risksthe process',
#  'process implement',
#  'implement risk',
#  'risk response',
#  'response plan',
#  'plan',
#  'tracking',
#  'identify',
#  'identify risk',
#  'risk',
#  'monitoring',
#  'monitor',
#  'residual risk',
#  'risk',
#  'identify',
#  'identify new',
#  'new risk',
#  'risk',
#  'evaluate',
#  'evaluate risk',
#  'risk process',
#  'process effectiveness',
#  'effectiveness',
#  'project',
#  'project',
#  'process',
#  'process interact',
#  'process',
#  'process knowledge',
#  'knowledge area',
#  'area describe',
#  'describe detail',
#  'detail section',
#  '',
#  'a.',
#  '',
#  'project risk',
#  'risk uncertain',
#  'uncertain event',
#  'event condition',
#  'condition',
#  'occur',
#  'occur',
#  'positive',
#  'positive negative',
#  'negative effect',
#  'effect',
#  'project',
#  'project objective',
#  'objective scope',
#  '',
#  'schedule',
#  'schedule',
#  'cost',
#  'cost',
#  'quality',
#  'quality',
#  'risk',
#  'risk may',
#  'may',
#  'cause',
#  'cause',
#  'occur',
#  'occur',
#  'may',
#  'may',
#  'impact',
#  'impact',
#  '',
#  '',
#  'may give',
#  'give potential',
#  'potential requirement',
#  'requirement',
#  'assumption',
#  'assumption',
#  'constraint',
#  'constraint',
#  'condition',
#  'condition create',
#  'create possibility',
#  'negative',
#  'negative positive',
#  'positive outcome',
#  'outcome',
#  'example',
#  'example',
#  'cause',
#  'cause could',
#  'could include',
#  'include requirement',
#  'environmental',
#  'environmental permit',
#  'permit work',
#  'work',
#  'limited',
#  'limited personnel',
#  'personnel assign',
#  'assign design',
#  'design',
#  'project',
#  'risk',
#  'risk permit',
#  'permit',
#  'may',
#  'may take',
#  'take long',
#  'long plan',
#  'plan issue',
#  'issue',
#  '',
#  'case',
#  'case opportunity',
#  'opportunity',
#  'additional',
#  'additional development',
#  'development personnel',
#  'personnel may',
#  'may become',
#  'become available',
#  'available participate',
#  'participate design',
#  'design',
#  'assign',
#  'assign project',
#  'project',
#  'either',
#  'uncertain',
#  'uncertain event',
#  'event occur',
#  'occur',
#  'may',
#  'may impact',
#  'impact project',
#  'project',
#  '',
#  '',
#  'cost',
#  'cost',
#  'schedule',
#  'schedule',
#  'quality',
#  'quality',
#  'performance',
#  'performance',
#  'risk',
#  'risk condition',
#  'condition may',
#  'may include',
#  'include aspect',
#  'aspect project',
#  'project organization',
#  'organization',
#  'environment contribute',
#  'project',
#  'project risk',
#  'risk',
#  'immature',
#  'immature project',
#  'project management',
#  'management practice',
#  'practice',
#  'lack',
#  'lack integrate',
#  'integrated management',
#  'management',
#  'system',
#  'concurrent',
#  'concurrent multiple',
#  'multiple project',
#  'project',
#  '',
#  '',
#  'external participant',
#  'participant outside',
#  'outside project',
#  'project direct',
#  'direct control',
#  'control',
#  '',
#  'project risk',
#  'risk origin',
#  '',
#  'uncertainty present',
#  'present project',
#  'project',
#  'know',
#  'know risk',
#  'risk identify',
#  'analyze',
#  'analyze',
#  'make',
#  'make possible',
#  'possible plan',
#  'plan response',
#  'response risk',
#  'risk',
#  'know',
#  'know risk',
#  'risk manage',
#  'manage proactively',
#  'proactively',
#  'assign',
#  'assign',
#  '',
#  '',
#  'unknown',
#  'unknown risk',
#  'risk manage',
#  'manage proactively',
#  'proactively therefore',
#  'therefore may',
#  'may assign',
#  'assign management',
#  '',
#  '',
#  'negative',
#  'negative project',
#  'project risk',
#  'risk occur',
#  'occur consider',
#  'consider issue',
#  'issue',
#  'individual',
#  'individual project',
#  'project risk',
#  'risk different',
#  'different overall',
#  'overall project',
#  'project risk',
#  'risk',
#  'overall',
#  'overall project',
#  'project risk',
#  'risk represent',
#  'represent effect',
#  'effect',
#  'uncertainty project',
#  'project whole',
#  'whole',
#  '',
#  'sum individual',
#  'individual risk',
#  'risk',
#  'project',
#  'project',
#  '',
#  'include',
#  'include source',
#  'source',
#  'project uncertainty',
#  'uncertainty',
#  'represent',
#  'represent exposure',
#  'exposure stakeholder',
#  'stakeholder implication',
#  'implication',
#  '',
#  'project',
#  '',
#  'positive',
#  'positive negative',
#  'negative',
#  'organization',
#  'organization',
#  'perceive risk',
#  'risk effect',
#  'effect',
#  'uncertainty project',
#  'project organizational',
#  'organizational objective',
#  'objective',
#  'organization',
#  'organization stakeholder',
#  'stakeholder willing',
#  'willing',
#  'accept varying',
#  'vary degree',
#  'degree risk',
#  'risk depend',
#  'depend risk',
#  'risk attitude',
#  'attitude',
#  'risk',
#  'risk attitude',
#  '',
#  'organization stakeholder',
#  'stakeholder may',
#  'may influence',
#  'influence number',
#  'number factor',
#  'factor',
#  'broadly',
#  'broadly classified',
#  'classify',
#  'theme',
#  'theme risk',
#  'risk appetite',
#  '',
#  'degree',
#  'degree uncertainty',
#  'uncertainty entity',
#  'entity willing',
#  'willing take',
#  'take anticipation',
#  'anticipation reward',
#  'reward',
#  'risk',
#  'risk tolerance',
#  'tolerance',
#  'degree',
#  'degree',
#  'amount',
#  '',
#  'volume',
#  'volume risk',
#  'risk',
#  'organization',
#  'individual withstand',
#  'withstand',
#  'risk',
#  'risk threshold',
#  '',
#  'refer',
#  'refer measure',
#  'measure along',
#  'level',
#  'level uncertainty',
#  'uncertainty level',
#  'level impact',
#  'impact stakeholder',
#  'stakeholder may',
#  'may specific',
#  'specific interest',
#  'interest',
#  'risk',
#  'risk threshold',
#  '',
#  '',
#  'accept',
#  'accept risk',
#  'risk',
#  'risk',
#  'risk threshold',
#  '',
#  '',
#  'organization tolerate',
#  'tolerate risk',
#  'risk',
#  'example',
#  'example',
#  'organization',
#  'organization risk',
#  'risk attitude',
#  'attitude may',
#  'may include',
#  'include',
#  '',
#  'uncertainty',
#  'threshold',
#  'risk',
#  'risk level',
#  'level unacceptable',
#  'unacceptable',
#  'risk',
#  'risk tolerance',
#  'tolerance point',
#  '',
#  'organization may',
#  'may select',
#  'select different',
#  'different risk',
#  'risk response',
#  'response',
#  'positive',
#  'positive negative',
#  'negative risk',
#  'risk commonly',
#  'commonly refer',
#  'referred opportunity',
#  'opportunity threat',
#  'threat',
#  '',
#  'project may',
#  'accept',
#  'accept risk',
#  'risk',
#  'tolerance',
#  'tolerance balance',
#  'balance reward',
#  'reward may',
#  'gain',
#  'gain take',
#  'take risk',
#  'risk',
#  'positive',
#  'positive risk',
#  'risk offer',
#  'offer opportunity',
#  'opportunity',
#  'limit',
#  'limit risk',
#  'risk tolerance',
#  'tolerance may',
#  'may pursued',
#  'pursue order',
#  'order',
#  'enhance',
#  'enhance value',
#  'value',
#  'example',
#  'example',
#  'adopt',
#  'adopt aggressive',
#  'aggressive resource',
#  'resource optimization',
#  'optimization technique',
#  'technique risk',
#  'risk take',
#  'take anticipation',
#  'anticipation reward',
#  'reward use',
#  'use few',
#  'few resource',
#  'resource',
#  'individual',
#  'individual group',
#  'group adopt',
#  'attitude',
#  'attitude',
#  'risk',
#  'risk influence',
#  'influence way',
#  '',
#  '',
#  'risk',
#  'risk attitude',
#  'attitude drive',
#  'drive perception',
#  'perception',
#  'tolerance',
#  'tolerance',
#  'bias',
#  'bias',
#  'make',
#  'make explicit',
#  'explicit wherever',
#  'wherever possible',
#  'possible',
#  'consistent',
#  'consistent approach',
#  'risk',
#  'risk develop',
#  'develop project',
#  'project',
#  'communication',
#  'communication risk',
#  'risk handle',
#  'handle open',
#  'open honest',
#  'honest',
#  'risk',
#  'risk response',
#  'response reflect',
#  'reflect organization',
#  'organization perceive',
#  'perceive balance',
#  'balance risk',
#  'risk take',
#  'take risk',
#  'risk avoidance',
#  'avoidance',
#  'successful',
#  'successful',
#  '',
#  'commit',
#  'committed address',
#  'address risk',
#  'risk management',
#  'management proactively',
#  'proactively consistently',
#  'consistently',
#  'project',
#  'project',
#  'conscious',
#  'conscious choice',
#  'choice make',
#  'make level',
#  'level',
#  'organization actively',
#  'actively identify',
#  'identify',
#  'pursue effective',
#  'effective risk',
#  'risk management',
#  'management life',
#  'life',
#  'project',
#  '',
#  'project risk',
#  'risk could',
#  'could exist',
#  'exist moment',
#  '',
#  'project initiate',
#  'initiate',
#  'move',
#  'move forward',
#  '',
#  'project',
#  'proactive',
#  'proactive focus',
#  'focus risk',
#  'risk management',
#  'management likely',
#  'likely lead',
#  'lead problem',
#  'problem arise',
#  'arise unmanaged',
#  'threat',
#  'threat',
#  '',
#  '',
#  '',
#  '',
#  'perform',
#  'perform quantitative',
#  '',
#  '',
#  '',
#  '',
#  'plan',
#  'plan risk',
#  'risk management',
#  'management plan',
#  'plan risk',
#  'risk management',
#  'management process',
#  'process define',
#  'define conduct',
#  'conduct risk',
#  'risk management',
#  'management activity',
#  'activity',
#  'project',
#  'key',
#  'key benefit',
#  'benefit process',
#  'process ensure',
#  'ensure',
#  'degree',
#  'type',
#  'type',
#  'visibility',
#  'visibility risk',
#  'risk management',
#  'management',
#  'commensurate risk',
#  '',
#  'importance project',
#  '',
#  'organization',
#  'risk',
#  'risk management',
#  'management plan',
#  'plan vital',
#  'vital communicate',
#  'communicate obtain',
#  'obtain agreement',
#  'support',
#  'support stakeholder',
#  'stakeholder ensure',
#  'ensure risk',
#  'risk management',
#  'management process',
#  'process support',
#  'support perform',
#  'perform effectively',
#  'effectively project',
#  'project life',
#  'life cycle',
#  'cycle',
#  'input',
#  'input',
#  'tool',
#  'tool technique',
#  'technique',
#  'output',
#  'output process',
#  'process depict',
#  'depict figure',
#  'figure',
#  'figure',
#  'figure depict',
#  'depict',
#  'datum',
#  '',
#  'process',
#  'process',
#  'input',
#  'tool',
#  'tool technique',
#  'technique output',
#  'output',
#  '',
#  'project management',
#  'management plan',
#  'plan',
#  'analytical',
#  'analytical technique',
#  'technique',
#  'risk',
#  'risk management',
#  'management plan',
#  'plan',
#  '',
#  'project',
#  'charter',
#  'expert',
#  '',
#  'judgment',
#  'stakeholder',
#  'stakeholder',
#  'register',
#  'meeting',
#  'meeting',
#  'enterprise',
#  'enterprise',
#  'environmental factor',
#  'factor',
#  'organizational',
#  'organizational process',
#  'process asset',
#  'asset figure',
#  'figure',
#  'plan',
#  'plan risk',
#  'risk management',
#  'management input',
#  'input',
#  'tool',
#  'tool technique',
#  'technique',
#  'output',
#  '',
#  'project risk',
#  'risk management',
#  'management',
#  '',
#  'project',
#  'charter develop',
#  'develop project',
#  'project',
#  'charter',
#  'plan',
#  'plan risk',
#  'risk management',
#  'management',
#  'enterprise',
#  'enterprise develop',
#  'develop project',
#  'project',
#  'environmental management',
#  'management factor',
#  'factor risk',
#  'risk plan',
#  'plan',
#  'organizational',
#  'organizational',
#  'management management',
#  'management process',
#  'process asset',
#  'asset',
#  'plan plan',
#  'plan',
#  '',
#  'perform',
#  'perform',
#  'identify',
#  'identify quantitative',
#  '',
#  'identify risk',
#  'risk risk',
#  'risk analysis',
#  'analysis stakeholder',
#  'stakeholder stakeholder',
#  'stakeholder',
#  'register',
#  'perform',
#  'perform',
#  'qualitative',
#  'qualitative plan',
#  'plan risk',
#  'risk enterprise',
#  'enterprise risk',
#  'risk analysis',
#  'analysis response',
#  '',
#  'organization figure',
#  'figure',
#  'plan',
#  'plan risk',
#  'risk management',
#  '',
#  'datum',
#  '',
#  'careful',
#  'careful',
#  'explicit planning',
#  'planning enhance',
#  'enhance probability',
#  'probability success',
#  'success risk',
#  'risk management',
#  'management process',
#  'process',
#  'plan',
#  'planning also',
#  'also important',
#  'important provide',
#  'provide sufficient',
#  'sufficient resource',
#  'resource time',
#  'time risk',
#  'risk management',
#  'management activity',
#  'activity establish',
#  'establish agree',
#  'agree',
#  'basis',
#  'basis evaluate',
#  'evaluate risk',
#  'risk',
#  'plan',
#  'plan risk',
#  'risk management',
#  'management process',
#  'process begin',
#  'begin project',
#  'project conceive',
#  'complete',
#  'complete early',
#  'early project',
#  'project planning',
#  'planning',
#  '',
#  'plan',
#  'plan risk',
#  'risk management',
#  'management input',
#  'input',
#  '',
#  'project management',
#  'management plan',
#  'plan plan',
#  'plan risk',
#  'risk management',
#  'management',
#  'approve',
#  'approve subsidiary',
#  'subsidiary management',
#  'management plan',
#  'plan baseline',
#  'baseline take',
#  'take consideration',
#  'consideration order',
#  'order make',
#  'make risk',
#  'risk management',
#  'management plan',
#  'plan consistent',
#  'consistent',
#  'risk',
#  'risk management',
#  'management plan',
#  'plan also',
#  'also component',
#  '',
#  'project management',
#  'management plan',
#  'plan',
#  '',
#  'project management',
#  'management plan',
#  'plan provide',
#  'provide',
#  'current',
#  'current state',
#  'state riskaffecte',
#  'riskaffected area',
#  'area include',
#  'include scope',
#  '',
#  'schedule',
#  'schedule',
#  'cost',
#  'cost',
#  '',
#  '',
#  'project',
#  'describe',
#  'describe section',
#  'section',
#  'project',
#  'project',
#  'provide',
#  'provide various',
#  'various input',
#  'highlevel',
#  'risk',
#  'risk',
#  '',
#  '',
#  'project description',
#  'description',
#  '',
#  'highlevel requirement',
#  'requirement',
#  '',
#  'stakeholder',
#  'stakeholder',
#  'describe',
#  'describe section',
#  'section',
#  'stakeholder',
#  'stakeholder',
#  'register',
#  'contain',
#  'contain detail',
#  'detail related',
#  'related project',
#  'project stakeholder',
#  'stakeholder',
#  'provide',
#  'provide overview',
#  'role',
#  'role',
#  '',
#  'enterprise',
#  'enterprise',
#  'environmental factor',
#  'factor describe',
#  'describe section',
#  'section',
#  'enterprise',
#  'enterprise',
#  'environmental factor',
#  'factor',
#  'influence plan',
#  'plan risk',
#  'risk management',
#  'management process',
#  'process include',
#  'include',
#  'limited',
#  'limited',
#  'risk',
#  'risk attitude',
#  'attitude',
#  '',
#  'threshold',
#  'tolerance',
#  'tolerance describe',
#  '',
#  'degree risk',
#  'risk',
#  'organization',
#  'withstand',
#  '',
#  'organizational',
#  'organizational process',
#  'process asset',
#  'asset describe',
#  'describe section',
#  'section',
#  'organizational',
#  'organizational process',
#  'process asset',
#  ...]

# %% [markdown]
# ### Remove doubles

# %%
flat_text_bok_lemma = list(dict.fromkeys(flat_text_bok_lemma))
flat_text_pmi_lemma = list(dict.fromkeys(flat_text_pmi_lemma))

# %% [markdown]
# ### Remove None values

# %%
flat_text_bok_lemma = [i for i in flat_text_bok_lemma if i !='']
flat_text_pmi_lemma = [i for i in flat_text_pmi_lemma if i !='']

# %%
flat_text_pmi_lemma
# Out:
# ['chapter introduction',
#  'introduction project',
#  'project management',
#  'practice',
#  'practice standard',
#  'guide',
#  'guide use',
#  'use tool',
#  'tool',
#  'technique',
#  'process',
#  'process identifi',
#  'identifi',
#  'management body',
#  'body knowledge',
#  'knowledge',
#  'guide fourth',
#  'standard',
#  'standard target',
#  'target audience',
#  'audience participate',
#  'participate management',
#  'management project',
#  'project',
#  'include',
#  'project manager',
#  'manager',
#  'project personnel',
#  'personnel',
#  'contract',
#  'contract personnel',
#  'supervisor',
#  'project stakeholder',
#  'stakeholder',
#  'describe process',
#  'activity',
#  'input',
#  'output',
#  'output specifi',
#  'specifi',
#  'knowledge area',
#  'area',
#  'provide',
#  'provide information',
#  'information',
#  'signifi can',
#  'can process',
#  'can',
#  'perform',
#  'perform execute',
#  'execute',
#  'necessary',
#  'perform process',
#  'process implement',
#  'implement',
#  'leave',
#  'leave subject',
#  'subject forum',
#  'handbook',
#  'manual',
#  'course',
#  'chapter',
#  'chapter include',
#  'include follow',
#  'follow section',
#  'section',
#  'purpose',
#  'purpose practice',
#  'project risk',
#  'risk management',
#  'management',
#  'defi nition',
#  'nition',
#  'role',
#  'good',
#  'good risk',
#  'management practice',
#  'critical',
#  'critical success',
#  'success factor',
#  'factor',
#  'management purpose',
#  'provide standard',
#  'management practitioner',
#  'practitioner stakeholder',
#  'aspect',
#  'management recognize',
#  'recognize good',
#  'good practice',
#  'practice project',
#  'project time',
#  'globally',
#  'globally applicable',
#  'applicable consistently',
#  'consistently apply',
#  'apply',
#  'descriptive purpose',
#  'purpose rather',
#  'rather',
#  'use',
#  'used training',
#  'train educational',
#  'educational purpose',
#  'management cover',
#  'cover risk',
#  'management apply',
#  'apply single',
#  'single project',
#  'p',
#  'edition',
#  'risk program',
#  'portfolio',
#  'portfolio project',
#  'basis',
#  'basis practice',
#  'consistent chapter',
#  'emphasize',
#  'emphasize concept',
#  'concept principle',
#  'principle relate',
#  'relate',
#  'align',
#  'align pmi',
#  'figure',
#  'figure compare',
#  'compare purpose',
#  'edition textbook',
#  'textbook',
#  'resource',
#  'resource practice',
#  'organized',
#  'organize',
#  'main',
#  'main section',
#  'introductory',
#  'introductory material',
#  'material include',
#  'include framework',
#  'framework',
#  'principle',
#  'context',
#  'introduction',
#  'management process',
#  'principle underlie',
#  'underlie',
#  'process follow',
#  'follow plan',
#  'plan risk',
#  'identify',
#  'identify risk',
#  'risk',
#  'perform qualitative',
#  'qualitative risk',
#  'risk analysis',
#  'analysis',
#  'perform quantitative',
#  'quantitative risk',
#  'plan',
#  'risk response',
#  'response',
#  'process describe',
#  'describe chapter',
#  'chapter address',
#  'address follow',
#  'follow',
#  'topic',
#  'topic purpose',
#  'purpose objective',
#  'objective process',
#  'factor process',
#  'c tool',
#  'tool technique',
#  'technique process',
#  'process document',
#  'document result',
#  'result process',
#  'glossary term',
#  'term use',
#  'use practice',
#  'principle fundamental',
#  'fundamental effective',
#  'effective',
#  'comprehensive',
#  'successful',
#  'successful project',
#  'principle state',
#  'state general',
#  'general level',
#  'level several',
#  'several reason',
#  'reason',
#  'principle expect',
#  'expect agree',
#  'agree',
#  'valid',
#  'valid future',
#  'technique constantly',
#  'constantly evolve',
#  'evolve',
#  'principle stability',
#  'stability',
#  'different',
#  'different project',
#  'organization',
#  'situation',
#  'situation require',
#  'require different',
#  'different approach',
#  'particular',
#  'management discipline',
#  'discipline contain',
#  'contain',
#  'process apply',
#  'apply large',
#  'large small',
#  'small project',
#  'management effective',
#  'effective practice',
#  'practice tailor',
#  'tailor project',
#  'organizational culture',
#  'culture',
#  'process asset',
#  'asset',
#  'many',
#  'many different',
#  'different way',
#  'way conduct',
#  'conduct risk',
#  'management may',
#  'may comply',
#  'management present',
#  'present practice',
#  'principle applicable',
#  'applicable project',
#  'project carry',
#  'carry global',
#  'global context',
#  'ecte',
#  'ecte many',
#  'many business',
#  'business organizational',
#  'organizational arrangement',
#  'arrangement participant',
#  'participant',
#  'example',
#  'joint',
#  'joint venture',
#  'venture commercial',
#  'company',
#  'government',
#  'government nongovernment',
#  'nongovernment organization',
#  'crosscultural',
#  'crosscultural environment',
#  'environment often',
#  'often find',
#  'find project',
#  'project team',
#  'team',
#  'principle describe',
#  'use check',
#  'check organization',
#  'organization process',
#  'practitioner',
#  'practitioner establish',
#  'establish process',
#  'process specifi',
#  'particular situation',
#  'organization compare',
#  'thus',
#  'thus validate',
#  'validate good',
#  'good project',
#  'management include',
#  'include process',
#  'process concerned',
#  'concerned conducting',
#  'management planning',
#  'planning',
#  'monitoring',
#  'monitor control',
#  'edition also',
#  'also state',
#  'state objective',
#  'management increase',
#  'increase probability',
#  'probability impact',
#  'impact positive',
#  'positive event',
#  'event',
#  'impact negative',
#  'negative event',
#  'risk uncertain',
#  'uncertain event',
#  'event condition',
#  'condition',
#  'occur',
#  'positive',
#  'positive negative',
#  'negative effect',
#  'effect project',
#  'project objective',
#  'objective',
#  'objective include',
#  'schedule',
#  'cost',
#  'quality',
#  'management aim',
#  'aim identify',
#  'risk advance',
#  'occurrence',
#  'provide actionoriented',
#  'actionoriented information',
#  'orientation',
#  'orientation require',
#  'require consideration',
#  'consideration event',
#  'event may',
#  'may',
#  'may occur',
#  'occur therefore',
#  'therefore describe',
#  'describe term',
#  'term',
#  'probability occurrence',
#  'occurrence addition',
#  'addition dimension',
#  'dimension',
#  'impact objective',
#  'management optional',
#  'optional activity',
#  'activity essential',
#  'essential successful',
#  'applied project',
#  'project hence',
#  'hence include',
#  'include project',
#  'project plan',
#  'plan operational',
#  'operational document',
#  'document',
#  'way',
#  'become',
#  'become integral',
#  'integral part',
#  'part',
#  'aspect managing',
#  'managing project',
#  'phase',
#  'group',
#  'many project',
#  'process address',
#  'address planning',
#  'concept',
#  'design',
#  'daily',
#  'management execution',
#  'execution',
#  'process often',
#  'often assume',
#  'assume unrealistic',
#  'unrealistic degree',
#  'degree certainty',
#  'therefore',
#  'need',
#  'need include',
#  'include treatment',
#  'treatment',
#  'management address',
#  'address',
#  'uncertainty project',
#  'project estimate',
#  'estimate assumption',
#  'assumption',
#  'build',
#  'extend',
#  'instance',
#  'project scheduling',
#  'scheduling provide',
#  'provide date',
#  'date critical',
#  'critical path',
#  'path base',
#  'base activity',
#  'activity duration',
#  'duration resource',
#  'resource availability',
#  'availability assume',
#  'know',
#  'quantitative',
#  'analysis explore',
#  'explore',
#  'uncertainty estimate',
#  'estimate duration',
#  'duration may',
#  'may provide',
#  'provide alternative',
#  'alternative date',
#  'path realistic',
#  'realistic give',
#  'give risk',
#  'substitute',
#  'contrary',
#  'management require',
#  'require',
#  'scheduling',
#  'budgeting',
#  'change',
#  'management perform',
#  'perform level',
#  'level best',
#  'practice available',
#  'available',
#  'management add',
#  'add perspective',
#  'perspective project',
#  'risk output',
#  'process add',
#  'add value',
#  'value take',
#  'take risk',
#  'risk account',
#  'account',
#  'management provide',
#  'provide basis',
#  'estimate',
#  'amount',
#  'cost schedule',
#  'reserve',
#  'reserve need',
#  'need cover',
#  'action',
#  'action require',
#  'required level',
#  'level confi',
#  'dence meeting',
#  'meeting',
#  'risk affect',
#  'affect project',
#  'early',
#  'early stage',
#  'level',
#  'level risk',
#  'risk exposure',
#  'exposure maximum',
#  'maximum information',
#  'situation mean',
#  'project go',
#  'go forward',
#  'forward little',
#  'little know',
#  'know time',
#  'time',
#  'may different',
#  'way approach',
#  'approach project',
#  'different risk',
#  'risk implication',
#  'implication',
#  'situation recognize',
#  'recognize',
#  'realistic',
#  'realistic project',
#  'plan expectation',
#  'expectation result',
#  'result',
#  'applicable',
#  'project life',
#  'life cycle',
#  'cycle',
#  'early project',
#  'cycle risk',
#  'risk recognize',
#  'management continue',
#  'continue add',
#  'value',
#  'project planning',
#  'planning progress',
#  'progress information',
#  'information become',
#  'become available',
#  'available aspect',
#  'aspect component',
#  'project environment',
#  'environment',
#  'well',
#  'well corresponding',
#  'correspond assumption',
#  'assumption constraint',
#  'constraint',
#  'balance project',
#  'exibility',
#  'exibility knowledge',
#  'risk need',
#  'need review',
#  'review regularly',
#  'regularly optimize',
#  'optimize plan',
#  'plan develop',
#  'develop',
#  'true',
#  'true project',
#  'plan become',
#  'become set',
#  'set fundamental',
#  'fundamental decision',
#  'decision',
#  'agreement',
#  'place',
#  'option',
#  'option make',
#  'make substantial',
#  'substantial change',
#  'change capture',
#  'capture opportunity',
#  'opportunity mitigate',
#  'threat',
#  'threat reduce',
#  'reduce',
#  'project execution',
#  'process monitor',
#  'monitor change',
#  'project undergoe',
#  'undergoe new',
#  'new risk',
#  'risk may',
#  'may emerge',
#  'emerge appropriate',
#  'appropriate response',
#  'response develop',
#  'check',
#  'check exist',
#  'exist risk',
#  'risk long',
#  'long plausible',
#  'plausible',
#  'management play',
#  'play role',
#  'role provide',
#  'provide realistic',
#  'realistic expectation',
#  'expectation',
#  'completion date',
#  'date cost',
#  'cost project',
#  'project even',
#  'even option',
#  'option change',
#  'change future',
#  'finally',
#  'project closure',
#  'closure',
#  'riskrelate',
#  'riskrelate lesson',
#  'lesson review',
#  'review order',
#  'order contribute',
#  'contribute organizational',
#  'organizational learning',
#  'learn support',
#  'support continuous',
#  'continuous improvement',
#  'improvement',
#  'management valuable',
#  'valuable component',
#  'management enhance',
#  'enhance value',
#  'management conduct',
#  'conduct',
#  'consistent',
#  'consistent exist',
#  'exist organizational',
#  'organizational practice',
#  'practice policy',
#  'policy',
#  'addition',
#  'process involve',
#  'involved project',
#  'conduct way',
#  'way appropriate',
#  'appropriate project',
#  'recognize business',
#  'business challenge',
#  'challenge well',
#  'multicultural',
#  'multicultural environment',
#  'associate',
#  'associate increasingly',
#  'increasingly global',
#  'global environment',
#  'environment include',
#  'include many',
#  'many joint',
#  'venture project',
#  'project customer',
#  'customer',
#  'supplier',
#  'workforce',
#  'workforce spread',
#  'spread around',
#  'management plan',
#  'process may',
#  'may require',
#  'require decision',
#  'decision appropriate',
#  'appropriate level',
#  'level management',
#  'reassign personnel',
#  'establish',
#  'budget',
#  'make',
#  'make commitment',
#  'commitment other',
#  'other outside',
#  'outside project',
#  'regulator',
#  'rule',
#  'rule account',
#  'accounting',
#  'law',
#  'conduct compliance',
#  'compliance internal',
#  'external requirement',
#  'requirement',
#  'management always',
#  'always conduct',
#  'conduct ethical',
#  'ethical basis',
#  'keep',
#  'ethic',
#  'ethic conduct',
#  'responsibility',
#  'realism',
#  'professionalism',
#  'fair dealing',
#  'deal other',
#  'other',
#  'characteristic',
#  'characteristic successful',
#  'effective project',
#  'benefi ts',
#  'robust',
#  'robust communication',
#  'communication',
#  'consultation stakeholder',
#  'enable',
#  'management general',
#  'risk identifi',
#  'carry',
#  'carry realistic',
#  'realistic objective',
#  'objective way',
#  'way subject',
#  'subject political',
#  'political unreasonable',
#  'unreasonable infl',
#  'uence',
#  'conduct project',
#  'degree',
#  'level detail',
#  'detail',
#  'sophistication',
#  'sophistication tool',
#  'amount time',
#  'resource apply',
#  'management proportion',
#  'proportion characteristic',
#  'management value',
#  'value add',
#  'add outcome',
#  'outcome',
#  'large',
#  'large project',
#  'project provide',
#  'provide value',
#  'value important',
#  'important customer',
#  'customer would',
#  'would theoretically',
#  'theoretically require',
#  'require resource',
#  'attention',
#  'attention project',
#  'management would',
#  'would small',
#  'smaller',
#  'internal',
#  'project conduct',
#  'fl exible',
#  'exible deadline',
#  'deadline',
#  'process scale',
#  'scale appropriate',
#  'process review',
#  'review periodically',
#  'periodically determine',
#  'decision make',
#  'make process',
#  'process remain',
#  'remain appropriate',
#  'appropriate',
#  'management figure',
#  'management specifi',
#  'criterion',
#  'process list',
#  'list chapter',
#  'chapter deal',
#  'deal process',
#  'general',
#  'general criterion',
#  'success include',
#  'include recognize',
#  'recognize value',
#  'value risk',
#  'recognize valuable',
#  'valuable discipline',
#  'discipline provide',
#  'provide positive',
#  'positive potential',
#  'potential return',
#  'return investment',
#  'investment organizational',
#  'organizational',
#  'stakeholder internal',
#  'team member',
#  'member',
#  'individual',
#  'individual commitmentresponsibility',
#  'commitmentresponsibility',
#  'project participant',
#  'participant stakeholder',
#  'stakeholder accept',
#  'accept responsibility',
#  'responsibility undertaking',
#  'undertaking riskrelate',
#  'riskrelate activity',
#  'activity require',
#  'everybodys responsibility',
#  'open',
#  'open honest',
#  'honest communication',
#  'involve',
#  'action attitude',
#  'attitude hinder',
#  'communication project',
#  'risk reduce',
#  'reduce effectiveness',
#  'management term',
#  'term proactive',
#  'proactive approach',
#  'effective decisionmaking',
#  'decisionmake',
#  'commitment establish',
#  'establish risk',
#  'management align',
#  'align organization',
#  'organization goal',
#  'goal value',
#  'require high',
#  'high level',
#  'level managerial',
#  'managerial support',
#  'support',
#  'discipline handle',
#  'handle risk',
#  'risk require',
#  'require approval',
#  'approval response',
#  'response other',
#  'other level',
#  'risk effort',
#  'effort scale',
#  'scale project',
#  'management activity',
#  'activity consistent',
#  'consistent value',
#  'organization level',
#  'level project',
#  'scale',
#  'organizational constraint',
#  'management appropriate',
#  'appropriate potential',
#  'potential value',
#  'integration',
#  'integration project',
#  'management exist',
#  'exist vacuum',
#  'isolate',
#  'isolated project',
#  'require correct',
#  'correct execution',
#  'execution project',
#  'illustrate',
#  'illustrate figure',
#  'conclusion',
#  'conclusion principle',
#  'management describe',
#  'describe practice',
#  'appropriately',
#  'appropriately apply',
#  'base',
#  'organizational environment',
#  'ts implement',
#  'implement accord',
#  'accord good',
#  'practice principle',
#  'principle organizational',
#  'take',
#  'take decision',
#  'decision perform',
#  'perform action',
#  'action open',
#  'unbiased',
#  'chapter principle',
#  'principle concept',
#  'introduction chapter',
#  'chapter introduce',
#  'introduce key',
#  'key idea',
#  'idea require',
#  'understand',
#  'apply project',
#  'project follow',
#  'describe',
#  'concept generally',
#  'generally consistent',
#  'consistent approach',
#  'management commonly',
#  'commonly use',
#  'terminology',
#  'terminology may',
#  'may differ',
#  'differ detail',
#  'process deal',
#  'deal subsequent',
#  'subsequent chapter',
#  'chapter practice',
#  'discuss',
#  'defi',
#  'risk word',
#  'word risk',
#  'risk use',
#  'use many',
#  'many way',
#  'everyday language',
#  'language various',
#  'various specialist',
#  'specialist discipline',
#  'discipline',
#  'consistent risk',
#  'management standard',
#  'standard process',
#  'process description',
#  'description',
#  'risk give',
#  'give',
#  'edition follow',
#  'follow project',
#  'nition include',
#  'key',
#  'key dimension',
#  'dimension risk',
#  'risk uncertainty',
#  'uncertainty effect',
#  'assess',
#  'assess importance',
#  'importance project',
#  'dimension must',
#  'must considered',
#  'consider',
#  'uncertainty',
#  'uncertainty dimension',
#  'dimension may',
#  'may describe',
#  'describe use',
#  'use term',
#  'probability effect',
#  'effect may',
#  'call',
#  'impact though',
#  'descriptor',
#  'descriptor possible',
#  'possible',
#  'risk include',
#  'include distinct',
#  'distinct event',
#  'event uncertain',
#  'clearly',
#  'clearly describe',
#  'condition less',
#  'less specifi',
#  'also',
#  'also may',
#  'may give',
#  'risk also',
#  'also encompass',
#  'encompass uncertain',
#  'event could',
#  'could negative',
#  'could',
#  'could positive',
#  'positive effect',
#  'effect',
#  'type',
#  'type risk',
#  'risk call',
#  'respectively',
#  'opportunity',
#  'important',
#  'important address',
#  'address threat',
#  'allow',
#  'allow gain',
#  'ciencie',
#  'ciencie address',
#  'address analysis',
#  'coordinate',
#  'coordinate response',
#  'response overlap',
#  'reinforce',
#  'uncertain future',
#  'future event',
#  'condition may',
#  'would',
#  'would matter',
#  'important distinguish',
#  'distinguish risk',
#  'risk riskrelate',
#  'riskrelate feature',
#  'feature',
#  'cause',
#  'cause event',
#  'event circumstance',
#  'circumstance currently',
#  'currently exist',
#  'exist certain',
#  'certain exist',
#  'exist future',
#  'give rise',
#  'rise risk',
#  'conditional',
#  'conditional future',
#  'condition would',
#  'would directly',
#  'directly affect',
#  'affect',
#  'objective associate',
#  'associate risk',
#  'risk occur',
#  'causeriskeffect',
#  'causeriskeffect chain',
#  'chain use',
#  'structured risk',
#  'risk statement',
#  'statement risk',
#  'risk description',
#  'description ensure',
#  'ensure',
#  'element',
#  'element properly',
#  'properly describe',
#  'describe see',
#  'see section',
#  'risk event',
#  'event occur',
#  'cease',
#  'cease become',
#  'become uncertain',
#  'uncertain',
#  'threat occur',
#  'occur may',
#  'call issue',
#  'issue problem',
#  'problem opportunity',
#  'opportunity occur',
#  'issuesproblem',
#  'management action',
#  'action outside',
#  'outside scope',
#  'individual risk',
#  'risk overall',
#  'overall project',
#  'risk useful',
#  'useful consider',
#  'consider project',
#  'level individual',
#  'risk specifi',
#  'may affect',
#  'may positively',
#  'positively negatively',
#  'negatively affect',
#  'task',
#  'understanding',
#  'understand individual',
#  'assist',
#  'assist determine',
#  'determine apply',
#  'apply effort',
#  'resource enhance',
#  ...]

# %% [markdown]
# ## TF-IDF

# %%
def TF(text):    
    doc = CountVectorizer()
    word_count=doc.fit_transform(text)
    tfidf_transformer=TfidfTransformer(smooth_idf=True,use_idf=True)
    tfidf_transformer.fit(word_count)
    df_idf = pd.DataFrame(tfidf_transformer.idf_, index=doc.get_feature_names(),columns=["idf_weights"])
    df_idf.sort_values(by=['idf_weights'],ascending=False).head()
    return df_idf
TF_IDF_bok = TF(flat_text_bok_lemma)
TF_IDF_pmi = TF(flat_text_pmi_lemma)

# %%
TF_IDF_bok
# Out:
#             idf_weights
# ability        7.433583
# able           7.433583
# academic       7.944409
# accept         6.963579
# acceptable     7.656727
# ...                 ...
# worked         8.349874
# workshop       7.944409
# would          7.944409
# write          7.944409
# zone           7.944409
#
# [1000 rows x 1 columns]

# %%
TF_IDF_pmi
# Out:
#                 idf_weights
# ability            7.460575
# able               7.460575
# accept             7.008590
# acceptable         6.841536
# acceptance         8.020191
# ...                     ...
# work               7.103900
# workassignment     8.307873
# workforce          8.307873
# workshop           8.713338
# would              6.698435
#
# [1175 rows x 1 columns]

# %% [markdown]
# ## Postagging

# %%
pos_bok, pos_pmi = [], []
for token in flat_text_bok_lemma:
    pos_bok.append(nltk.pos_tag([token]))
    
for token in flat_text_pmi_lemma:
    pos_pmi.append(nltk.pos_tag([token]))

# %%
pos_bok = [item for sublist in pos_bok for item in sublist]
pos_pmi = [item for sublist in pos_pmi for item in sublist]

# %%
pattern = 'NP: {<DT>?<JJ>*<NN>}'
cp = nltk.RegexpParser(pattern)
cs_bok = cp.parse(pos_bok)

cs_pmi = cp.parse(pos_pmi)

# %%
cs_pmi

# %%
data = [text_bok_cos, text_pmi_cos]

# %%
from sklearn.feature_extraction.text import CountVectorizer

count_vectorizer = CountVectorizer()
vector_matrix = count_vectorizer.fit_transform(data)


tokens = count_vectorizer.get_feature_names()

# %%
import pandas as pd

def create_dataframe(matrix, tokens):

    doc_names = [f'doc_{i+1}' for i, _ in enumerate(matrix)]
    df = pd.DataFrame(data=matrix, index=doc_names, columns=tokens)
    return(df)
x = create_dataframe(vector_matrix.toarray(),tokens)
x

# %%
from sklearn.metrics.pairwise import cosine_similarity

cosine_similarity_matrix = cosine_similarity(vector_matrix)
create_dataframe(cosine_similarity_matrix,['doc_1','doc_2'])

# %% [markdown]
# # Spacy Rule

# %% [markdown]
# ## Rule1

# %%
def rule1(text): 
    doc = nlp(text) 
    sent = []
    for token in doc: 
        if (token.pos_=='VERB'):
            phrase = "" 
            for sub_tok in token.lefts: 
                if (sub_tok.dep_ in ['nsubj','nsubjpass']) and (sub_tok.pos_ in ['NOUN','PROPN','PRON'] ):
                    phrase += sub_tok.text 
                    phrase += " "+token.text
                    for sub_tok in token.rights:
                        if (sub_tok.dep_ in ['dobj']) and (sub_tok.pos_ in ['NOUN','PROPN'] ):
                            phrase += " "+sub_tok.text
                            sent.append(phrase)
    return sent

# %%
output_bok_rule1, output_pmi_rule1 = [],[]

for i in sent_bok:
    output_bok_rule1.append(rule1(i))
    

for i in sent_pmi:
    output_pmi_rule1.append(rule1(i))
    
df_rule1_bok = pd.DataFrame({'sentences':sent_bok,'output':output_pmi_rule1})
df_rule1_pmi = pd.DataFrame({'sentences':sent_pmi,'output':output_pmi_rule1})

# %% [markdown]
# ### Separate subject, verb and object for PMBOK

# %%
verb_dict = dict()
dis_dict = dict()
dis_list = []

# iterating over all the sentences
for i in range(len(df_rule1_pmi)):
    
    # sentence containing the output
    sentence = df_rule1_pmi.loc[i,'sentences']
    # output of the sentence
    output = df_rule1_pmi.loc[i,'output']
    
    # iterating over all the outputs from the sentence
    for sent in output:
        
        # separate subject, verb and object
        n1 = sent.split()[:1]
        v = sent.split()[1]
        n2 = sent.split()[2:]
        
        # append to list, along with the sentence
        dis_dict = {'sentence':sentence,'Noun1':n1,'Verb':v,'Noun2':n2}
        dis_list.append(dis_dict)
        
        # counting the number of sentences containing the verb
        verb = sent.split()[1]
        if verb in verb_dict:
            verb_dict[verb]+=1
        else:
            verb_dict[verb]=1

df_sep_bok_rule1 = pd.DataFrame(dis_list)

# %% [markdown]
# ### Separate subject, verb and object for PMI

# %%
verb_dict = dict()
dis_dict = dict()
dis_list = []

# iterating over all the sentences
for i in range(len(df_rule1_bok)):
    
    # sentence containing the output
    sentence = df_rule1_bok.loc[i,'sentences']
    # output of the sentence
    output = df_rule1_bok.loc[i,'output']
    
    # iterating over all the outputs from the sentence
    for sent in output:
        
        # separate subject, verb and object
        n1 = sent.split()[:1]
        v = sent.split()[1]
        n2 = sent.split()[2:]
        
        # append to list, along with the sentence
        dis_dict = {'sentence':sentence,'Noun1':n1,'Verb':v,'Noun2':n2}
        dis_list.append(dis_dict)
        
        # counting the number of sentences containing the verb
        verb = sent.split()[1]
        if verb in verb_dict:
            verb_dict[verb]+=1
        else:
            verb_dict[verb]=1

df_sep_pmi_rule1 = pd.DataFrame(dis_list)

# %% [markdown]
# ## Rule 2

# %%
# function for rule 2
def rule2(text):
    
    doc = nlp(text)

    pat = []
    
    # iterate over tokens
    for token in doc:
        phrase = ''
        # if the word is a subject noun or an object noun
        if (token.pos_ == 'NOUN')\
            and (token.dep_ in ['dobj','pobj','nsubj','nsubjpass']):
            
            # iterate over the children nodes
            for subtoken in token.children:
                # if word is an adjective or has a compound dependency
                if (subtoken.pos_ == 'ADJ') or (subtoken.dep_ == 'compound'):
                    phrase += subtoken.text + ' '
                    
            if len(phrase)!=0:
                phrase += token.text
             
        if  len(phrase)!=0:
            pat.append(phrase)
        
    
    return pat

# %%
output_bok_rule2, output_pmi_rule2 = [],[]

for i in sent_bok:
    output_bok_rule2.append(rule2(i))
    

for i in sent_pmi:
    output_pmi_rule2.append(rule2(i))
    
df_rule2_bok = pd.DataFrame({'sentences':sent_bok,'output':output_bok_rule2})
df_rule2_pmi = pd.DataFrame({'sentences':sent_pmi,'output':output_pmi_rule2})

# %% [markdown]
# ### Separate subject, verb and object for PMBOK

# %%
verb_dict = dict()
dis_dict = dict()
dis_list = []

# iterating over all the sentences
for i in range(len(df_rule2_bok)):
    
    # sentence containing the output
    sentence = df_rule2_bok.loc[i,'sentences']
    # output of the sentence
    output = df_rule2_bok.loc[i,'output']
    
    # iterating over all the outputs from the sentence
    for sent in output:
        
        # separate subject, verb and object
        n1 = sent.split()[:1]
        v = sent.split()[1]
        n2 = sent.split()[2:]
        
        # append to list, along with the sentence
        dis_dict = {'sentence':sentence,'Noun1':n1,'Verb':v,'Noun2':n2}
        dis_list.append(dis_dict)
        
        # counting the number of sentences containing the verb
        verb = sent.split()[1]
        if verb in verb_dict:
            verb_dict[verb]+=1
        else:
            verb_dict[verb]=1

df_sep_bok_rule2 = pd.DataFrame(dis_list)

# %% [markdown]
# ### Separate subject, verb and object for PMI

# %%
verb_dict = dict()
dis_dict = dict()
dis_list = []

# iterating over all the sentences
for i in range(len(df_rule2_pmi)):
    
    # sentence containing the output
    sentence = df_rule2_pmi.loc[i,'sentences']
    # output of the sentence
    output = df_rule2_pmi.loc[i,'output']
    
    # iterating over all the outputs from the sentence
    for sent in output:
        
        # separate subject, verb and object
        n1 = sent.split()[:1]
        v = sent.split()[1]
        n2 = sent.split()[2:]
        
        # append to list, along with the sentence
        dis_dict = {'sentence':sentence,'Noun1':n1,'Verb':v,'Noun2':n2}
        dis_list.append(dis_dict)
        
        # counting the number of sentences containing the verb
        verb = sent.split()[1]
        if verb in verb_dict:
            verb_dict[verb]+=1
        else:
            verb_dict[verb]=1

df_sep_pmi_rule2 = pd.DataFrame(dis_list)

# %%
df_sep_pmi_rule2
# Out:
#                                                sentence           Noun1  \
# 0     chapter introduction project management instit...     [institute]
# 1     chapter introduction project management instit...     [knowledge]
# 2     chapter introduction project management instit...        [fourth]
# 3     practice standards targeted audiences particip...      [practice]
# 4     practice standards targeted audiences particip...    [management]
# ...                                                 ...             ...
# 1494  .. managing contingency reserves reserves may ...      [reserves]
# 1495  techniques required allow project manager asse...      [required]
# 1496  tools managing time buffers closely integrated...    [integrated]
# 1497  tools also required tracking progress spending...      [tracking]
# 1498  tools also required tracking progress spending...  [consolidated]
#
#            Verb                      Noun2
# 0           pmi      [practice, standards]
# 1         pmbok                         []
# 2           pmi                [standards]
# 3     standards                         []
# 4      projects                         []
# ...         ...                        ...
# 1494   reserves                         []
# 1495      level  [dence, success, project]
# 1496   projects                         []
# 1497   progress                         []
# 1498     manner                         []
#
# [1499 rows x 4 columns]

# %% [markdown]
# ## Rule 4

# %%
def rule4(text):
    
    doc = nlp(text)
    
    sent = []
    
    for token in doc:
        
        # If the token is a verb
        if (token.pos_=='AUX'):
            
            phrase =''
            
            # Only extract noun or pronoun subjects
            for sub_tok in token.lefts:
                
                if  (sub_tok.pos_ in ['NOUN','PROPN','PRON']):
                    
                    # Add subject to the phrase
                    phrase += sub_tok.text

                    # Save the root of the word in phrase
                    phrase += ' '+token.lemma_ 

                    # Check for noun or pronoun direct objects
                    for sub_tok in token.rights:
                        
                        # Save the object in the phrase
                        if (sub_tok.pos_ in ['NOUN','PROPN']):
                                    
                            phrase += ' '+sub_tok.text
                            sent.append(phrase)
            
    return sent

# %%
output_bok_rule4, output_pmi_rule4 = [],[]

for i in sent_bok:
    output_bok_rule4.append(rule4(text))
    

for i in sent_pmi:
    output_pmi_rule4.append(rule4(i))
    
df_rule4_bok = pd.DataFrame({'sentences':sent_bok,'output':output_bok_rule4})
df_rule4_pmi = pd.DataFrame({'sentences':sent_pmi,'output':output_pmi_rule4})

# %%
text='Those actions the project management team can take unilaterally, if the performing organization has a prescribed procurement, contracting, or purchasing department'

# %% [markdown]
# ### Separate subject, verb and object for PMBOK

# %%
verb_dict = dict()
dis_dict = dict()
dis_list = []

# iterating over all the sentences
for i in range(len(df_rule4_bok)):
    
    # sentence containing the output
    sentence = df_rule4_bok.loc[i,'sentences']
    # output of the sentence
    output = df_rule4_bok.loc[i,'output']
    
    # iterating over all the outputs from the sentence
    for sent in output:
        
        # separate subject, verb and object
        n1 = sent.split()[:1]
        v = sent.split()[1]
        n2 = sent.split()[2:]
        
        # append to list, along with the sentence
        dis_dict = {'sentence':sentence,'Noun1':n1,'IS/Have':v,'Noun2':n2}
        dis_list.append(dis_dict)
        
        # counting the number of sentences containing the verb
        verb = sent.split()[1]
        if verb in verb_dict:
            verb_dict[verb]+=1
        else:
            verb_dict[verb]=1

df_sep_bok_rule4 = pd.DataFrame(dis_list)

# %%
df_sep_bok_rule4
# Out:
#                                               sentence           Noun1  \
# 0     project risk management project risk manageme...  [organization]
# 1    objectives project risk management increase li...  [organization]
# 2    figure provides overview project risk manageme...  [organization]
# 3    plan risk managementthe process defining condu...  [organization]
# 4                                                    .  [organization]
# ..                                                 ...             ...
# 680  latter responses initially planned , required ...  [organization]
# 681                   recommended preventive actions .  [organization]
# 682  activities ensure future performance project w...  [organization]
# 683  ... project management plan updates approved c...  [organization]
# 684  elements project management plan may updated p...  [organization]
#
#     IS/Have          Noun2
# 0      have  [procurement]
# 1      have  [procurement]
# 2      have  [procurement]
# 3      have  [procurement]
# 4      have  [procurement]
# ..      ...            ...
# 680    have  [procurement]
# 681    have  [procurement]
# 682    have  [procurement]
# 683    have  [procurement]
# 684    have  [procurement]
#
# [685 rows x 4 columns]

# %% [markdown]
# ### Separate subject, verb and object for PMI

# %%
verb_dict = dict()
dis_dict = dict()
dis_list = []

# iterating over all the sentences
for i in range(len(df_rule4_pmi)):
    
    # sentence containing the output
    sentence = df_rule4_pmi.loc[i,'sentences']
    # output of the sentence
    output = df_rule4_pmi.loc[i,'output']
    
    # iterating over all the outputs from the sentence
    for sent in output:
        
        # separate subject, verb and object
        n1 = sent.split()[:1]
        v = sent.split()[1]
        n2 = sent.split()[2:]
        
        # append to list, along with the sentence
        dis_dict = {'sentence':sentence,'Noun1':n1,'IS/Have':v,'Noun2':n2}
        dis_list.append(dis_dict)
        
        # counting the number of sentences containing the verb
        verb = sent.split()[1]
        if verb in verb_dict:
            verb_dict[verb]+=1
        else:
            verb_dict[verb]=1

df_sep_pmi_rule4 = pd.DataFrame(dis_list)

# %%
df_sep_pmi_rule4
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from bertopic import BERTopic

# %%
model_rse = BERTopic(language="english")

# %%
topics_rse,probs = model_rse.fit_transform(text_bok)

# %%
for i in range(len(topics_rse)):
    print(str(model_rse.get_topic(topics_rse[i]))+"\n")

# %%
badwords=[]
def remove_weak(lists,topics,models):
    for i in range(len(lists)):
        for j in range(len(models.get_topic(topics[i]))):
            if models.get_topic(topics[i])[j][1]==0:
                badwords.append(models.get_topic(topics[i])[j])
            
            
    for test in range(len(topics)):
    
        for i in badwords:
            if i in models.get_topic(topics[test]):
                models.get_topic(topics[test]).remove(i)
remove_weak(text_bok,topics_rse,model_rse)

# %%
import ktrain

# %%
tm_lemma = ktrain.text.get_topic_model(text_bok_lda,n_features=100)

# %%
tm_lemma.build(text_bok_lda,threshold=0.25)

# %%
tm_lemma.print_topics(show_counts=True,)

# %%
tm_lemma.visualize_documents(doc_topics=tm_lemma.get_doctopics())
